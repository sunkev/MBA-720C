# %%
# Import the requisite packages
# Pandas for data manipulation
import pandas as pd
import numpy as np

# Matplotlib for basic plotting
import matplotlib.pyplot as plt

#import data
review_df = pd.read_csv("Datafiniti_Amazon_Consumer_Reviews_of_Amazon_Products_May19.csv")
review_df.head()
# Out:
#                      id             dateAdded           dateUpdated  \
# 0  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 1  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 2  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 3  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 4  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
#
#                                                 name                  asins  \
# 0  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 1  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 2  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 3  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 4  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
#
#           brand                                         categories  \
# ...

# %%
#determine the count of users for each rating
group_by_ratings = review_df.groupby('reviews.rating').size()
sorted_ratings = group_by_ratings.sort_values(ascending=False)
ratings_df = pd.DataFrame(sorted_ratings.rename('No of Users')).reset_index()

ratings_df
# Out:
#    reviews.rating  No of Users
# 0               5        19897
# 1               4         5648
# 2               3         1206
# 3               1          965
# 4               2          616

# %%
#create a barchart for count of users for each rating
number_of_users = ratings_df["No of Users"]
ratings_labels = ratings_df["reviews.rating"]

plt.bar(ratings_labels, number_of_users, color='b', align="center")

# Give the chart a title, x label, and y label
plt.title("Number of Ratings")
plt.xlabel("Rating")
plt.ylabel("Number of Reviews")

plt.savefig("number_of_ratings.png")
plt.show()

# %%
#count the number of reviews by category
group_by_categories = review_df.groupby('primaryCategories')

category_count = group_by_categories.count().reset_index()
category_count
# Out:
#              primaryCategories     id  dateAdded  dateUpdated   name  asins  \
# 0       Animals & Pet Supplies      6          6            6      6      6
# 1                  Electronics  13995      13995        13995  13995  13995
# 2        Electronics,Furniture      2          2            2      2      2
# 3            Electronics,Media    185        185          185    185    185
# 4              Health & Beauty  12071      12071        12071  12071  12071
# 5                Home & Garden      2          2            2      2      2
# 6              Office Supplies      9          9            9      9      9
# 7  Office Supplies,Electronics    386        386          386    386    386
# 8     Toys & Games,Electronics   1676       1676         1676   1676   1676
#
#    brand  categories  imageURLs   keys  ...  reviews.didPurchase  \
# 0      6           6          6      6  ...                    0
# 1  13995       13995      13995  13995  ...                    9
# ...

# %%
#find average reviews of each category

category_rating_avg = group_by_categories.mean().reset_index()
category_rating_avg
# Out:
#              primaryCategories    reviews.id  reviews.numHelpful  \
# 0       Animals & Pet Supplies           NaN                 NaN
# 1                  Electronics  1.840066e+08            0.552430
# 2        Electronics,Furniture           NaN            0.000000
# 3            Electronics,Media           NaN            2.724324
# 4              Health & Beauty           NaN                 NaN
# 5                Home & Garden           NaN                 NaN
# 6              Office Supplies           NaN                 NaN
# 7  Office Supplies,Electronics           NaN            0.435233
# 8     Toys & Games,Electronics           NaN            0.118138
#
#    reviews.rating
# 0        4.500000
# 1        4.563987
# 2        5.000000
# 3        4.664865
# 4        4.449756
# 5        4.500000
# 6        5.000000
# 7        4.554404
# 8        4.531026

# %%
#create barchart of average reviews by category

average_rating = category_rating_avg["reviews.rating"]
categories = category_rating_avg["primaryCategories"]
x_axis = np.arange(len(categories))

plt.bar(x_axis, average_rating, color='b', align="center")
plt.xticks(x_axis, x_axis)

# Give the chart a title, x label, and y label
plt.title("Average Rating of Categories")
plt.xlabel("Category")
plt.ylabel("Average Rating")

# plt.legend(loc='upper right')

plt.savefig("avg_ratings_by_category.png")
plt.show()
